# %%
# name =input('Pleased to meet you, can we know your name? ')
# print('You have a nice name')
# age =input('How old are you? ')
# answer =input("You seem quite younger, are you sure you're "+age+ "years? ")
# if answer =='No':
#     input('Please can we know your real age? ')
# else:
#     print('Thanks '+name+ ' Once again, you are welcome.')
# Out:
# Pleased to meet you, can we know your name? Peace
# You have a nice name
# How old are you? 12
# You seem quite younger, are you sure you're 12years? Yes
# Thanks Peace Once again, you are welcome.

# %%
# print(12)
# Out:
# 12

# %%
# print('this is living')
# Out:
# this is living

# %%
import pandas as pd

# %%
data = pd.read_csv('Sleep_Efficiency.csv')
data
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep_duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = data[['Age', 'Gender']]
y = data['Sleep_duration']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=10)

# %%
x_test
# Out:
#      Age  Gender
# 303   51    Male
# 131   36  Female
# 116   50    Male
# 305   65    Male
# 65    21    Male
# ..   ...     ...
# 88    48    Male
# 207   41  Female
# 81    29    Male
# 56    54    Male
# 191   27  Female
#
# [91 rows x 2 columns]

# %%
# data['Gender'] = data['Gender'].str.replace('[^\d.]', '', regex=True)
model = LinearRegression()
model.fit(data[['Age', 'Gender']], data.Sleep_duration)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # data['Gender'] = data['Gender'].str.replace('[^\d.]', '', regex=True)
# ----> 2 model = LinearRegression()
#       3 model.fit(data[['Age', 'Gender']], data.Sleep_duration)
#
# NameError: name 'LinearRegression' is not defined
